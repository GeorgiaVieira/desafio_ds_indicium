# %%
print("Hello")

# %%
#Iportações
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap

# %%
df = pd.read_csv("teste_indicium_precificacao.csv")
num_linhas = df.shape[0]

# %%
print(df.describe())

# %%
# Retirar os valores muito altos de preço para não poluir. Outliers?
preco_medio = df['price'].mean()
limite_inferior = df_bairro_acima_da_media['price'].quantile(0.15)
limite_superior = df['price'].quantile(0.98)

coluna_agrupamento = "bairro"

# %%
d_ffiltrado = df[df["price"] >= limite_inferior]

# %%
d_ffiltrado = df_filtrado.groupby(coluna_agrupamento)[["latitude", "longitude", "price"]].mean().reset_index()

# %%
mapa = folium.Map(location=[df_filtrado["latitude"].mean(), df_filtrado["longitude"].mean()], zoom_start=12)

# %%
heat_data = d_ffiltrado[['latitude', 'longitude', 'price']].values  # Dados para o HeatMap
HeatMap(heat_data, radius=15, blur=10, max_zoom=1).add_to(mapa)

# %%
var = f'row["{coluna_agrupamento}"]'

# %%
for _, row in d_ffiltrado.iterrows():
    folium.Marker(
        location=[row["latitude"], row["longitude"]],
        icon=folium.DivIcon(
            html=f'<div style="font-size: 10pt; color: black; font-weight: bold;">{row["bairro"]}</div>'
        )
    ).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
string = "O cachorro comeu: {coluna_agrupamento}"

# %%
string
# Out:
# 'O cachorro comeu: {coluna_agrupamento}'

# %%
df["room_type"].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)
